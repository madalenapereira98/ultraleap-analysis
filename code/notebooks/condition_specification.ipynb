# %% [markdown]
# Import public packages and functions

# %%
import os
import importlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import seaborn as sns
import statistics as stat
import json
from scipy.stats import kstest

# %%
def get_repo_path_in_notebook():
    """
    Finds path of repo from Notebook.
    Start running this once to correctly find
    other modules/functions
    """
    path = os.getcwd()
    repo_name = 'ultraleap_analysis'

    while path[-len(repo_name):] != 'ultraleap_analysis':

        path = os.path.dirname(path)

    return path

# %%
repo_path = get_repo_path_in_notebook()
code_path = os.path.join(repo_path, 'code')
os.chdir(code_path)

# %% [markdown]
# Import own functions

# %%
import sig_processing.extract_scores as sc_ext
import sig_processing.predict as pred
import plotting.boxplotting as bxplt
import statistic.stat_analysis as statis

# %% [markdown]
# ### Cohort Specifications

# %%
folder  = 'patientdata'

# %% [markdown]
# Finger Tapping

# %%
ft = 'ft'
feat_df_path_ft = os.path.join(
    repo_path,
    'EDA',
    folder,
    ft, 
    'new_features.csv'
    )

X_df_ft = pd.read_csv(feat_df_path_ft, index_col=0)
# Load scores/labels
y_with_nan_ft = sc_ext.get_labels_for_feat_df(X_df_ft)
y_ft = np.array([i for i in y_with_nan_ft if not np.isnan(i)])
try:
    X_df_ft = sc_ext.remove_non_score_rows(X_df_ft, y_with_nan_ft)
except KeyError:
    print('Non-scored/non-existing rows/blocks have already been scored.')
# Out:
# No scores for block ('b1', 'ul020', 'm1s1', 'dt', 'ft', 'lh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm1s1', 'dt', 'ft', 'lh') or this combination does not exist
# No scores for block ('b3', 'ul020', 'm1s1', 'dt', 'ft', 'lh') or this combination does not exist

# %%
importlib.reload(statis)
# Out:
# <module 'statistic.stat_analysis' from 'c:\\Users\\madal\\Projects\\Thesis\\ultraleap_analysis\\code\\statistic\\stat_analysis.py'>

# %%
cond_ft = [file.split('_')[2] for file in X_df_ft['file']]

# %%
col_ft = ['Finger Tapping' for i in np.arange(0,len(y_ft))]
df_ft = pd.DataFrame({
    'task': col_ft,
    'cond':cond_ft
})
df_ft
# Out:
#                task  cond
# 0    Finger Tapping    m1
# 1    Finger Tapping    m1
# 2    Finger Tapping    m1
# 3    Finger Tapping    m1
# 4    Finger Tapping    m1
# ..              ...   ...
# 195  Finger Tapping  m0s0
# 196  Finger Tapping  m1s0
# 197  Finger Tapping  m1s0
# 198  Finger Tapping  m1s1
# 199  Finger Tapping  m0s1
#
# [200 rows x 2 columns]

# %% [markdown]
# Opening and Closing

# %%
oc = 'oc'
feat_df_path_oc = os.path.join(
    repo_path,
    'EDA',
    folder,
    oc, 
    'new_features.csv'
    )

X_df_oc = pd.read_csv(feat_df_path_oc, index_col=0)
# Load scores/labels
y_with_nan_oc = sc_ext.get_labels_for_feat_df(X_df_oc)
y_oc = np.array([i for i in y_with_nan_oc if not np.isnan(i)])
try:
    X_df_oc = sc_ext.remove_non_score_rows(X_df_oc, y_with_nan_oc)
except KeyError:
    print('Non-scored/non-existing rows/blocks have already been scored.')
# Out:
# No scores for block ('b1', 'ul020', 'm0s0', 'vr', 'oc', 'rh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm0s0', 'vr', 'oc', 'rh') or this combination does not exist
# No scores for block ('b1', 'ul020', 'm1s1', 'dt', 'oc', 'rh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm1s1', 'dt', 'oc', 'rh') or this combination does not exist
# No scores for block ('b1', 'ul020', 'm0s0', 'vr', 'oc', 'lh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm0s0', 'vr', 'oc', 'lh') or this combination does not exist
# No scores for block ('b1', 'ul020', 'm1s1', 'dt', 'oc', 'lh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm1s1', 'dt', 'oc', 'lh') or this combination does not exist

# %%
cond_oc = [file.split('_')[2] for file in X_df_oc['file']]

# %%
col_oc = ['Opening Closing' for i in np.arange(0,len(y_oc))]
df_oc = pd.DataFrame({
    'task': col_oc,
    'cond':cond_oc
})
df_oc
# Out:
#                 task  cond
# 0    Opening Closing    m1
# 1    Opening Closing    m1
# 2    Opening Closing    m1
# 3    Opening Closing    m1
# 4    Opening Closing    m1
# ..               ...   ...
# 157  Opening Closing  m1s0
# 158  Opening Closing  m1s1
# 159  Opening Closing  m1s1
# 160  Opening Closing  m0s1
# 161  Opening Closing  m0s1
#
# [162 rows x 2 columns]

# %% [markdown]
# Pronation Supination

# %%
ps = 'ps'
feat_df_path_ps = os.path.join(
    repo_path,
    'EDA',
    folder,
    ps, 
    'new_features.csv'
    )

X_df_ps = pd.read_csv(feat_df_path_ps, index_col=0)
# Load scores/labels
y_with_nan_ps = sc_ext.get_labels_for_feat_df(X_df_ps)
y_ps = np.array([i for i in y_with_nan_ps if not np.isnan(i)])
try:
    X_df_ps = sc_ext.remove_non_score_rows(X_df_ps, y_with_nan_ps)
except KeyError:
    print('Non-scored/non-existing rows/blocks have already been scored.')
# Out:
# No scores for block ('b1', 'ul020', 'm0s0', 'vr', 'ps', 'rh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm0s0', 'vr', 'ps', 'rh') or this combination does not exist
# No scores for block ('b1', 'ul020', 'm1s1', 'dt', 'ps', 'rh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm1s1', 'dt', 'ps', 'rh') or this combination does not exist
# No scores for block ('b1', 'ul020', 'm0s0', 'vr', 'ps', 'lh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm0s0', 'vr', 'ps', 'lh') or this combination does not exist
# No scores for block ('b1', 'ul020', 'm1s1', 'dt', 'ps', 'lh') or this combination does not exist
# No scores for block ('b2', 'ul020', 'm1s1', 'dt', 'ps', 'lh') or this combination does not exist

# %%
cond_ps = [file.split('_')[2] for file in X_df_ps['file']]

# %%
col_ps = ['Pronation Supination' for i in np.arange(0,len(y_ps))]
df_ps = pd.DataFrame({
    'task': col_ps,
    'cond':cond_ps
})
df_ps
# Out:
#                      task  cond
# 0    Pronation Supination    m1
# 1    Pronation Supination    m1
# 2    Pronation Supination    m1
# 3    Pronation Supination    m1
# 4    Pronation Supination    m1
# ..                    ...   ...
# 171  Pronation Supination  m1s0
# 172  Pronation Supination  m1s1
# 173  Pronation Supination  m1s1
# 174  Pronation Supination  m0s1
# 175  Pronation Supination  m0s1
#
# [176 rows x 2 columns]

# %%
df_tasks = pd.concat([df_ft,df_oc,df_ps])
df_tasks = df_tasks.reset_index(drop=True)

# %%
df_tasks[df_tasks['task'] == 'Pronation Supination']
# Out:
#                      task  cond
# 362  Pronation Supination    m1
# 363  Pronation Supination    m1
# 364  Pronation Supination    m1
# 365  Pronation Supination    m1
# 366  Pronation Supination    m1
# ..                    ...   ...
# 533  Pronation Supination  m1s0
# 534  Pronation Supination  m1s1
# 535  Pronation Supination  m1s1
# 536  Pronation Supination  m0s1
# 537  Pronation Supination  m0s1
#
# [176 rows x 2 columns]

# %%
pivot_table = df_tasks[['task','cond']].pivot_table(index='task', columns='cond', 
                                              aggfunc=len, fill_value=0)
print(pivot_table)
# Out:
# cond                  m0s0  m0s1  m1  m1s0  m1s1
# task
# Finger Tapping          24    20  46    51    59
# Opening Closing         21    16  43    41    41
# Pronation Supination    24    12  50    44    46

# %%
from tabulate import tabulate

# %%
# print(tabulate(pivot_table, headers='keys',tablefmt='latex'))
print(tabulate(pivot_table, headers='keys',tablefmt='pretty'))
# Out:
# +----------------------+------+------+----+------+------+
# |         task         | m0s0 | m0s1 | m1 | m1s0 | m1s1 |
# +----------------------+------+------+----+------+------+
# |    Finger Tapping    |  24  |  20  | 46 |  51  |  59  |
# |   Opening Closing    |  21  |  16  | 43 |  41  |  41  |
# | Pronation Supination |  24  |  12  | 50 |  44  |  46  |
# +----------------------+------+------+----+------+------+

# %%
fig = plt.figure(figsize=(15,22))
pivot_table.plot.bar(colormap='summer', rot=1)
plt.ylabel('Number of observations')
plt.xlabel('')
plt.legend(title='MDS-UPDRS Part III scores', bbox_to_anchor=(0.5, 1.08), loc='center', ncol=len(pivot_table.columns))
plt.yticks([0,20,40,60,80,100])
# Out:
# ([<matplotlib.axis.YTick at 0x16337b01eb0>,
#   <matplotlib.axis.YTick at 0x16337b01970>,
#   <matplotlib.axis.YTick at 0x16337b6cbb0>,
#   <matplotlib.axis.YTick at 0x163373e7850>,
#   <matplotlib.axis.YTick at 0x163373f1340>,
#   <matplotlib.axis.YTick at 0x163373f1df0>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])

# %%
X_df_ft
# Out:
#                               file  num_events  mean_max_dist  sd_max_dist  \
# 0     b1_ul001_m1_vr_ft_right.json        26.0       0.139824     0.006147
# 1     b2_ul001_m1_vr_ft_right.json        31.0       0.134933     0.004083
# 2     b1_ul001_m1_dt_ft_right.json        20.0       0.086324     0.019164
# 3     b2_ul001_m1_dt_ft_right.json        26.0       0.086305     0.016929
# 4     b3_ul001_m1_dt_ft_right.json        24.0       0.100558     0.010255
# ..                             ...         ...            ...          ...
# 195  b3_ul019_m0s0_dt_ft_left.json         9.0       0.044480     0.009061
# 196  b1_ul019_m1s0_vr_ft_left.json         4.0       0.023934     0.003339
# 197  b3_ul019_m1s0_vr_ft_left.json        22.0       0.025543     0.006056
# 198  b2_ul019_m1s1_vr_ft_left.json         4.0       0.020624     0.000347
# 199  b3_ul019_m0s1_dt_ft_left.json         5.0       0.042018     0.006991
#
#      coef_var_max_dist  slope_max_dist  decr_max_dist  mean_max_vel  \
# 0             0.043961       -0.000597       0.004762      2.756138
# 1             0.030256        0.000072      -0.021412      2.559501
# 2             0.222004       -0.001298      -0.319352      1.531217
# 3             0.196150       -0.001409      -0.185258      1.894720
# 4             0.101979       -0.000742      -0.153763      2.345756
# ..                 ...             ...            ...           ...
# 195           0.203708       -0.000566      -0.355184      0.397632
# 196           0.139512       -0.003846      -0.316802      0.347057
# 197           0.237108       -0.000138      -0.419691      0.345630
# 198           0.016828       -0.000240       0.286117      0.318934
# 199           0.166394       -0.005951      -0.198649      0.208265
#
#      sd_max_vel  coef_var_max_vel  ...  mean_tap_dur  sd_tap_dur  \
# 0      0.472769          0.171533  ...      0.418023    0.146259
# 1      0.425132          0.166100  ...      0.360868    0.031789
# 2      0.322006          0.210294  ...      0.487451    0.093077
# 3      0.857292          0.452464  ...      0.437970    0.093196
# 4      0.899337          0.383389  ...      0.427845    0.082475
# ..          ...               ...  ...           ...         ...
# 195    0.133423          0.335544  ...      0.445870    0.098635
# 196    0.071135          0.204966  ...      1.014140    0.327512
# 197    0.097573          0.282306  ...      0.467687    0.123651
# 198    0.032386          0.101545  ...      2.088555    2.056497
# 199    0.075892          0.364401  ...      2.468707    1.100433
#
#      coef_var_tap_dur  slope_tap_dur  mean_rms    sd_rms  slope_rms   sum_rms  \
# 0            0.349883       0.002214  0.070272  0.007038  -0.000641  1.756795
# 1            0.088091      -0.000501  0.077272  0.004883  -0.000028  2.318146
# 2            0.190946      -0.000302  0.050991  0.006480  -0.000532  0.968823
# 3            0.212792       0.007941  0.050254  0.007442  -0.000370  1.256361
# 4            0.192769      -0.001855  0.059499  0.004799  -0.000181  1.368483
# ..                ...            ...       ...       ...        ...       ...
# 195          0.221220       0.009685  0.027596  0.005413   0.001308  0.220768
# 196          0.322946       0.312935  0.010331  0.001545  -0.001780  0.030993
# 197          0.264387      -0.000102  0.012507  0.002469   0.000046  0.262650
# 198          0.984651       2.185150  0.008887  0.000092   0.000028  0.026662
# 199          0.445753       0.970097  0.030241  0.002985  -0.002282  0.120964
#
#      jerkiness   entropy
# 0    10.092632  6.683361
# 1     7.849825  6.683361
# 2    11.774737  6.683361
# 3    11.029105  6.673298
# 4    10.973734  6.681626
# ..         ...       ...
# 195   6.500339  6.643790
# 196   9.305886  6.572608
# 197   6.648331  6.682109
# 198   7.048833  6.678634
# 199  10.174150  6.577861
#
# [200 rows x 25 columns]

# %%
ls_feats_ft = ['num_events','mean_max_dist','mean_max_vel','sum_rms']

# %%
# Store test statistic and p-values
statistics = []
p_values = []

for column in ls_feats_ft:
        # standardize the data (to have mean 0, std. dev. 1) before applying the test
        standardized_data = (X_df_ft[column] - X_df_ft[column].mean()) / X_df_ft[column].std()
        stat, p_value = kstest(standardized_data, 'norm')
        statistics.append(stat)
        p_values.append(p_value)

# Create a DataFrame for easy visualization
normality_df = pd.DataFrame({
    'Feature': ls_feats_ft,
    'Statistic': statistics,
    'P-Value': p_values
})

normality_df = normality_df.sort_values(by='Statistic', ascending=False)
normality_df
# Out:
#          Feature  Statistic   P-Value
# 0     num_events   0.106678  0.019511
# 3        sum_rms   0.089535  0.076117
# 1  mean_max_dist   0.065766  0.337791
# 2   mean_max_vel   0.050212  0.675202

# %%
# Store test statistic and p-values
statistics = []
p_values = []

for column in X_df_ft.iloc[:,1:].columns:
        # standardize the data (to have mean 0, std. dev. 1) before applying the test
        standardized_data = (X_df_ft.iloc[:,1:][column] - X_df_ft.iloc[:,1:][column].mean()) / X_df_ft.iloc[:,1:][column].std()
        stat, p_value = kstest(standardized_data, 'norm')
        statistics.append(stat)
        p_values.append(p_value)

# Create a DataFrame for easy visualization
normality_df = pd.DataFrame({
    'Feature': X_df_ft.iloc[:,1:].columns,
    'Statistic': statistics,
    'P-Value': p_values
})

normality_df = normality_df.sort_values(by='Statistic', ascending=False)
normality_df
# Out:
#               Feature  Statistic       P-Value
# 17      slope_tap_dur   0.419238  2.278293e-32
# 15         sd_tap_dur   0.303238  8.166144e-17
# 14       mean_tap_dur   0.287749  3.728646e-15
# 4      slope_max_dist   0.237048  2.265882e-10
# 20          slope_rms   0.215192  1.311316e-08
# 16   coef_var_tap_dur   0.171941  1.220671e-05
# 5       decr_max_dist   0.165017  3.152966e-05
# 23            entropy   0.160971  5.389258e-05
# 12  coef_var_mean_vel   0.111822  1.237908e-02
# 0          num_events   0.106678  1.951080e-02
# 3   coef_var_max_dist   0.102858  2.697610e-02
# 19             sd_rms   0.087542  8.779984e-02
# 22          jerkiness   0.087148  9.028044e-02
# 13     slope_mean_vel   0.085954  9.816083e-02
# 21            sum_rms   0.083205  1.184812e-01
# 2         sd_max_dist   0.081530  1.324694e-01
# 8    coef_var_max_vel   0.077915  1.672382e-01
# 9       slope_max_vel   0.074376  2.079310e-01
# 7          sd_max_vel   0.070520  2.604595e-01
# 1       mean_max_dist   0.065766  3.377914e-01
# 10      mean_mean_vel   0.057566  5.030938e-01
# 18           mean_rms   0.057277  5.095643e-01
# 6        mean_max_vel   0.050212  6.752021e-01
# 11        sd_mean_vel   0.031749  9.839660e-01

# %%
ls_grouped_condition = []
count_a = 0
count_b = 0
count_c = 0
for cond in df_ft['cond']:
    if cond in ['m1','m1s1']:
        ls_grouped_condition.append('Treated')
        count_a+=1
    elif cond in ['m1s0','m0s1']:
        ls_grouped_condition.append('Partly treated')
        count_b+=1
    elif cond == 'm0s0':
        ls_grouped_condition.append('Untreated')
        count_c+=1
ls_grouped_condition
# Out:
# ['Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Treated',
#  'Partly treated',
#  'Untreated',
#  'Untreated',
#  'Untreated',
#  'Partly treated',
#  'Partly treated',
#  'Treated',
#  'Partly treated']

# %%
count_a,count_b,count_c
# Out:
# (105, 71, 24)

# %%
X_df_ft['file'].to_list()
# Out:
# ['b1_ul001_m1_vr_ft_right.json',
#  'b2_ul001_m1_vr_ft_right.json',
#  'b1_ul001_m1_dt_ft_right.json',
#  'b2_ul001_m1_dt_ft_right.json',
#  'b3_ul001_m1_dt_ft_right.json',
#  'b1_ul001_m1_vr_ft_left.json',
#  'b2_ul001_m1_vr_ft_left.json',
#  'b1_ul001_m1_dt_ft_left.json',
#  'b2_ul001_m1_dt_ft_left.json',
#  'b3_ul001_m1_dt_ft_left.json',
#  'b1_ul002_m1_vr_ft_right.json',
#  'b2_ul002_m1_vr_ft_right.json',
#  'b1_ul002_m1_dt_ft_right.json',
#  'b2_ul002_m1_dt_ft_right.json',
#  'b1_ul002_m1_vr_ft_left.json',
#  'b2_ul002_m1_vr_ft_left.json',
#  'b1_ul002_m1_dt_ft_left.json',
#  'b2_ul002_m1_dt_ft_left.json',
#  'b1_ul003_m1s0_vr_ft_right.json',
#  'b2_ul003_m1s0_vr_ft_right.json',
#  'b1_ul003_m1s0_dt_ft_right.json',
#  'b2_ul003_m1s0_dt_ft_right.json',
#  'b1_ul003_m1s1_vr_ft_right.json',
#  'b2_ul003_m1s1_vr_ft_right.json',
#  'b1_ul003_m1s1_dt_ft_right.json',
#  'b2_ul003_m1s1_dt_ft_right.json',
#  'b1_ul003_m1s0_vr_ft_left.json',
#  'b2_ul003_m1s0_vr_ft_left.json',
#  'b1_ul003_m1s0_dt_ft_left.json',
#  'b2_ul003_m1s0_dt_ft_left.json',
#  'b1_ul003_m1s1_vr_ft_left.json',
#  'b2_ul003_m1s1_vr_ft_left.json',
#  'b1_ul003_m1s1_dt_ft_left.json',
#  'b2_ul003_m1s1_dt_ft_left.json',
#  'b1_ul004_m1s0_vr_ft_right.json',
#  'b2_ul004_m1s0_vr_ft_right.json',
#  'b1_ul004_m1s0_dt_ft_right.json',
#  'b2_ul004_m1s0_dt_ft_right.json',
#  'b1_ul004_m1s1_vr_ft_right.json',
#  'b2_ul004_m1s1_vr_ft_right.json',
#  'b1_ul004_m1s1_dt_ft_right.json',
#  'b2_ul004_m1s1_dt_ft_right.json',
#  'b1_ul004_m1s0_vr_ft_left.json',
#  'b2_ul004_m1s0_vr_ft_left.json',
#  'b1_ul004_m1s0_dt_ft_left.json',
#  'b1_ul004_m1s1_vr_ft_left.json',
#  'b2_ul004_m1s1_vr_ft_left.json',
#  'b1_ul004_m1s1_dt_ft_left.json',
#  'b2_ul004_m1s1_dt_ft_left.json',
#  'b1_ul005_m1s1_vr_ft_right.json',
#  'b2_ul005_m1s1_vr_ft_right.json',
#  'b1_ul005_m1s1_dt_ft_right.json',
#  'b2_ul005_m1s1_dt_ft_right.json',
#  'b1_ul005_m1s1_vr_ft_left.json',
#  'b2_ul005_m1s1_vr_ft_left.json',
#  'b1_ul005_m1s1_dt_ft_left.json',
#  'b2_ul005_m1s1_dt_ft_left.json',
#  'b1_ul007_m0s0_vr_ft_right.json',
#  'b2_ul007_m0s0_vr_ft_right.json',
#  'b3_ul007_m0s0_vr_ft_right.json',
#  'b1_ul007_m1s0_dt_ft_right.json',
#  'b2_ul007_m1s0_dt_ft_right.json',
#  'b3_ul007_m1s0_dt_ft_right.json',
#  'b1_ul007_m1s1_vr_ft_right.json',
#  'b2_ul007_m1s1_vr_ft_right.json',
#  'b3_ul007_m1s1_vr_ft_right.json',
#  'b1_ul007_m0s1_dt_ft_right.json',
#  'b2_ul007_m0s1_dt_ft_right.json',
#  'b3_ul007_m0s1_dt_ft_right.json',
#  'b1_ul007_m0s0_vr_ft_left.json',
#  'b2_ul007_m0s0_vr_ft_left.json',
#  'b3_ul007_m0s0_vr_ft_left.json',
#  'b1_ul007_m1s0_dt_ft_left.json',
#  'b2_ul007_m1s0_dt_ft_left.json',
#  'b3_ul007_m1s0_dt_ft_left.json',
#  'b1_ul007_m1s1_vr_ft_left.json',
#  'b2_ul007_m1s1_vr_ft_left.json',
#  'b3_ul007_m1s1_vr_ft_left.json',
#  'b1_ul007_m0s1_dt_ft_left.json',
#  'b2_ul007_m0s1_dt_ft_left.json',
#  'b3_ul007_m0s1_dt_ft_left.json',
#  'b1_ul008_m0s0_dt_ft_right.json',
#  'b2_ul008_m0s0_dt_ft_right.json',
#  'b3_ul008_m0s0_dt_ft_right.json',
#  'b1_ul008_m1s0_vr_ft_right.json',
#  'b2_ul008_m1s0_vr_ft_right.json',
#  'b3_ul008_m1s0_vr_ft_right.json',
#  'b1_ul008_m1s1_dt_ft_right.json',
#  'b2_ul008_m1s1_dt_ft_right.json',
#  'b3_ul008_m1s1_dt_ft_right.json',
#  'b1_ul008_m0s1_vr_ft_right.json',
#  'b2_ul008_m0s1_vr_ft_right.json',
#  'b3_ul008_m0s1_vr_ft_right.json',
#  'b1_ul008_m0s0_dt_ft_left.json',
#  'b2_ul008_m0s0_dt_ft_left.json',
#  'b3_ul008_m0s0_dt_ft_left.json',
#  'b1_ul008_m1s0_vr_ft_left.json',
#  'b2_ul008_m1s0_vr_ft_left.json',
#  'b3_ul008_m1s0_vr_ft_left.json',
#  'b1_ul008_m1s1_dt_ft_left.json',
#  'b2_ul008_m1s1_dt_ft_left.json',
#  'b3_ul008_m1s1_dt_ft_left.json',
#  'b1_ul008_m0s1_vr_ft_left.json',
#  'b2_ul008_m0s1_vr_ft_left.json',
#  'b3_ul008_m0s1_vr_ft_left.json',
#  'b1_ul009_m1_dt_ft_right.json',
#  'b2_ul009_m1_dt_ft_right.json',
#  'b1_ul009_m1_st_ft_right.json',
#  'b2_ul009_m1_st_ft_right.json',
#  'b1_ul009_m1_dt_ft_left.json',
#  'b2_ul009_m1_dt_ft_left.json',
#  'b1_ul009_m1_st_ft_left.json',
#  'b2_ul009_m1_st_ft_left.json',
#  'b1_ul010_m0s0_dt_ft_left.json',
#  'b2_ul010_m0s0_dt_ft_left.json',
#  'b3_ul010_m0s0_dt_ft_left.json',
#  'b1_ul011_m0s0_st_ft_right.json',
#  'b2_ul011_m0s0_st_ft_right.json',
#  'b3_ul011_m0s0_st_ft_right.json',
#  'b1_ul011_m1s0_dt_ft_right.json',
#  'b2_ul011_m1s0_dt_ft_right.json',
#  'b3_ul011_m1s0_dt_ft_right.json',
#  'b1_ul011_m0s0_st_ft_left.json',
#  'b2_ul011_m0s0_st_ft_left.json',
#  'b3_ul011_m0s0_st_ft_left.json',
#  'b1_ul011_m1s0_dt_ft_left.json',
#  'b2_ul011_m1s0_dt_ft_left.json',
#  'b3_ul011_m1s0_dt_ft_left.json',
#  'b2_ul012_m1s0_st_ft_right.json',
#  'b1_ul012_m1s1_dt_ft_right.json',
#  'b2_ul012_m1s1_dt_ft_right.json',
#  'b1_ul012_m1s0_st_ft_left.json',
#  'b1_ul012_m1s1_dt_ft_left.json',
#  'b2_ul012_m1s1_dt_ft_left.json',
#  'b1_ul013_m1_vr_ft_right.json',
#  'b2_ul013_m1_vr_ft_right.json',
#  'b1_ul013_m1_st_ft_right.json',
#  'b2_ul013_m1_st_ft_right.json',
#  'b1_ul013_m1_vr_ft_left.json',
#  'b2_ul013_m1_vr_ft_left.json',
#  'b1_ul013_m1_st_ft_left.json',
#  'b2_ul013_m1_st_ft_left.json',
#  'b1_ul014_m1_dt_ft_right.json',
#  'b2_ul014_m1_dt_ft_right.json',
#  'b1_ul014_m1_dt_ft_left.json',
#  'b2_ul014_m1_dt_ft_left.json',
#  'b1_ul015_m1s1_vr_ft_right.json',
#  'b2_ul015_m1s1_vr_ft_right.json',
#  'b1_ul015_m1s1_vr_ft_left.json',
#  'b2_ul015_m1s1_vr_ft_left.json',
#  'b1_ul016_m1_vr_ft_right.json',
#  'b2_ul016_m1_vr_ft_right.json',
#  'b1_ul016_m1_dt_ft_right.json',
#  'b2_ul016_m1_dt_ft_right.json',
#  'b1_ul016_m1_vr_ft_left.json',
#  'b2_ul016_m1_vr_ft_left.json',
#  'b1_ul016_m1_dt_ft_left.json',
#  'b2_ul016_m1_dt_ft_left.json',
#  'b1_ul017_m1s0_vr_ft_right.json',
#  'b2_ul017_m1s0_vr_ft_right.json',
#  'b3_ul017_m1s0_vr_ft_right.json',
#  'b1_ul017_m1s1_vr_ft_right.json',
#  'b2_ul017_m1s1_vr_ft_right.json',
#  'b3_ul017_m1s1_vr_ft_right.json',
#  'b1_ul017_m0s1_dt_ft_right.json',
#  'b2_ul017_m0s1_dt_ft_right.json',
#  'b3_ul017_m0s1_dt_ft_right.json',
#  'b1_ul017_m1s0_vr_ft_left.json',
#  'b2_ul017_m1s0_vr_ft_left.json',
#  'b3_ul017_m1s0_vr_ft_left.json',
#  'b1_ul017_m1s1_vr_ft_left.json',
#  'b2_ul017_m1s1_vr_ft_left.json',
#  'b3_ul017_m1s1_vr_ft_left.json',
#  'b1_ul017_m0s1_dt_ft_left.json',
#  'b2_ul017_m0s1_dt_ft_left.json',
#  'b3_ul017_m0s1_dt_ft_left.json',
#  'b1_ul018_m1s0_st_ft_right.json',
#  'b2_ul018_m1s0_st_ft_right.json',
#  'b1_ul018_m1s1_dt_ft_right.json',
#  'b2_ul018_m1s1_dt_ft_right.json',
#  'b3_ul018_m1s1_dt_ft_right.json',
#  'b1_ul018_m1s0_st_ft_left.json',
#  'b2_ul018_m1s0_st_ft_left.json',
#  'b3_ul018_m1s0_st_ft_left.json',
#  'b1_ul018_m1s1_dt_ft_left.json',
#  'b2_ul018_m1s1_dt_ft_left.json',
#  'b3_ul018_m1s1_dt_ft_left.json',
#  'b1_ul019_m1s0_vr_ft_right.json',
#  'b2_ul019_m1s0_vr_ft_right.json',
#  'b3_ul019_m1s0_vr_ft_right.json',
#  'b2_ul019_m1s1_vr_ft_right.json',
#  'b3_ul019_m1s1_vr_ft_right.json',
#  'b3_ul019_m0s1_dt_ft_right.json',
#  'b1_ul019_m0s0_dt_ft_left.json',
#  'b2_ul019_m0s0_dt_ft_left.json',
#  'b3_ul019_m0s0_dt_ft_left.json',
#  'b1_ul019_m1s0_vr_ft_left.json',
#  'b3_ul019_m1s0_vr_ft_left.json',
#  'b2_ul019_m1s1_vr_ft_left.json',
#  'b3_ul019_m0s1_dt_ft_left.json']

# %%
subs = [sub.split('_')[1] for sub in X_df_ft['file']]
for sub in subs:
    if int(sub[-2:])>9:
        ls_subs.append(sub[-2:])
    else:
        ls_subs.append(sub[-1:])
ls_subs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 6
#       4         ls_subs.append(sub[-2:])
#       5     else:
# ----> 6         ls_subs.append(sub[-1:])
#       7 ls_subs
#
# NameError: name 'ls_subs' is not defined

# %%
# Create a sample dataset (replace this with your actual data)
import pandas as pd
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
data = {
    'num_events': X_df_ft['num_events'],
    'sum_rms': X_df_ft['sum_rms'],
    'mean_max_dist': X_df_ft['mean_max_dist'],
    'mean_max_vel': X_df_ft['mean_max_vel'],
    'subject': ls_subs,
    'condition': ls_grouped_condition
}

df = pd.DataFrame(data)

# List of continuous features
continuous_features = ['num_events', 'sum_rms', 'mean_max_dist', 'mean_max_vel']

# Perform Two-Way ANOVA for each continuous feature
for feature in continuous_features:
    formula = f'{feature} ~ C(subject) + C(condition) + C(subject):C(condition)'
    model = ols(formula, data=df).fit()
    anova_table = anova_lm(model)
    
    print(f"ANOVA results for {feature}:\n")
    print(anova_table)
    print("\n" + "="*40 + "\n")
# Out:
# ANOVA results for num_events:
#
#                             df       sum_sq     mean_sq          F  \
# C(subject)                17.0  5445.677071  320.333945  14.888909
# C(condition)               2.0   216.980566  108.490283   5.042556
# C(subject):C(condition)   34.0  1714.472540   50.425663   2.343751
# Residual                 170.0  3657.539286   21.514937        NaN
#
#                                PR(>F)
# C(subject)               1.490501e-25
# C(condition)             7.456659e-03
# C(subject):C(condition)  1.927756e-04
# Residual                          NaN
#
# ========================================
#
# ANOVA results for sum_rms:
#
#                             df     sum_sq   mean_sq          F        PR(>F)
# C(subject)                17.0  33.398725  1.964631  31.587274  9.683536e-44
# C(condition)               2.0   1.104201  0.552100   8.876654  2.153836e-04
# C(subject):C(condition)   34.0   5.739226  0.168801   2.713973  1.298793e-05
# Residual                 170.0  10.573475  0.062197        NaN           NaN
#
# ========================================
#
# ANOVA results for mean_max_dist:
#
#                             df    sum_sq   mean_sq          F        PR(>F)
# C(subject)                17.0  0.120754  0.007103  45.322747  4.938738e-54
# C(condition)               2.0  0.004036  0.002018  12.875580  6.212825e-06
# C(subject):C(condition)   34.0  0.011067  0.000325   2.076810  1.264666e-03
# Residual                 170.0  0.026643  0.000157        NaN           NaN
#
# ========================================
#
# ANOVA results for mean_max_vel:
#
#                             df     sum_sq   mean_sq          F        PR(>F)
# C(subject)                17.0  39.076529  2.298619  24.447694  5.267286e-37
# C(condition)               2.0   0.347168  0.173584   1.846210  1.609847e-01
# C(subject):C(condition)   34.0   8.388010  0.246706   2.623922  2.518860e-05
# Residual                 170.0  15.983728  0.094022        NaN           NaN
#
# ========================================

# %%
# Set up the figure and axes for subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle('Box Plots of Continuous Features by Subject and Score')
# Create box plots for each continuous feature
for i, feature in enumerate(continuous_features):
    row = i // 2
    col = i % 2
    ax = axes[row, col]
    
    sns.boxplot(data=df, x='condition', y=feature, hue='subject', ax=ax, )
    ax.set_title(f'{feature} by Subject and Score')
    ax.set_xlabel('subject')
    ax.set_ylabel(feature)
    ax.legend(title='subject')

plt.tight_layout()
plt.show()

# %%
# Create a sample dataset (replace this with your actual data)
import pandas as pd
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
data = {
    'num_events': X_df_ft['num_events'],
    'sum_rms': X_df_ft['sum_rms'],
    'mean_max_dist': X_df_ft['mean_max_dist'],
    'mean_max_vel': X_df_ft['mean_max_vel'],
    'condition': ls_grouped_condition,
    'score': y_ft
}

df = pd.DataFrame(data)

# List of continuous features
continuous_features = ['num_events', 'sum_rms', 'mean_max_dist', 'mean_max_vel']

# Perform Two-Way ANOVA for each continuous feature
for feature in continuous_features:
    formula = f'{feature} ~ C(condition) + C(score) + C(condition):C(score)'
    model = ols(formula, data=df).fit()
    anova_table = anova_lm(model)
    
    print(f"ANOVA results for {feature}:\n")
    print(anova_table)
    print("\n" + "="*40 + "\n")
# Out:
# ANOVA results for num_events:
#
#                           df       sum_sq     mean_sq          F        PR(>F)
# C(condition)             2.0   587.123303  293.561652   7.565979  6.923399e-04
# C(score)                 4.0  1911.777365  477.944341  12.318083  6.528445e-09
# C(condition):C(score)    8.0   996.774356  124.596795   3.211239  1.923820e-03
# Residual               187.0  7255.641294   38.800221        NaN           NaN
#
# ========================================
#
# ANOVA results for sum_rms:
#
#                           df     sum_sq   mean_sq          F        PR(>F)
# C(condition)             2.0   7.607208  3.803604  16.131531  3.442853e-07
# C(score)                 4.0  12.642953  3.160738  13.405061  1.264155e-09
# C(condition):C(score)    8.0   3.605286  0.450661   1.911305  6.050831e-02
# Residual               187.0  44.092156  0.235787        NaN           NaN
#
# ========================================
#
# ANOVA results for mean_max_dist:
#
#                           df    sum_sq   mean_sq          F        PR(>F)
# C(condition)             2.0  0.014462  0.007231  13.871117  2.414945e-06
# C(score)                 4.0  0.039099  0.009775  18.750317  5.614740e-13
# C(condition):C(score)    8.0  0.007295  0.000912   1.749179  8.967745e-02
# Residual               187.0  0.097486  0.000521        NaN           NaN
#
# ========================================
#
# ANOVA results for mean_max_vel:
#
#                           df     sum_sq   mean_sq          F        PR(>F)
# C(condition)             2.0   1.937656  0.968828   4.366099  1.402064e-02
# C(score)                 4.0  13.845857  3.461464  15.599357  4.955150e-11
# C(condition):C(score)    8.0   2.006486  0.250811   1.130298  3.447440e-01
# Residual               187.0  41.494905  0.221898        NaN           NaN
#
# ========================================

# %%
# Set up the figure and axes for subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Box Plots of Continuous Features by Condition and Score')
# Create box plots for each continuous feature
for i, feature in enumerate(continuous_features):
    row = i // 2
    col = i % 2
    ax = axes[row, col]
    
    sns.boxplot(data=df, x='condition', y=feature, hue='score', ax=ax, palette='summer')
    ax.set_title(f'{feature} by Condition and Score')
    ax.set_xlabel('Condition')
    ax.set_ylabel(feature)
    ax.legend(title='Score')

plt.tight_layout()
plt.show()

# %%
# Set up the figure and axes for subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Box Plots of Continuous Features by Condition and Score')

# Create box plots for each continuous feature
for i, feature in enumerate(continuous_features):
    row = i // 2
    col = i % 2
    ax = axes[row, col]
    
    sns.boxplot(data=df, x='score', y=feature, hue='condition', ax=ax)
    ax.set_title(f'{feature} by Score and Colored by Condition')
    ax.set_xlabel('Score')
    ax.set_ylabel(feature)
    ax.legend(title='Condition')

plt.tight_layout()
plt.show()

# %%
# Set the style of seaborn plots
sns.set(style="whitegrid")

# Example 1: Violin Plots
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='condition', y='num_events', hue='score', split=True)
plt.title('Violin Plot of num_events by Condition and Score')
plt.xlabel('Condition')
plt.ylabel('num_events')
plt.show()

# Example 2: Pairplot
sns.pairplot(df, hue='condition', diag_kind='kde')
plt.suptitle('Pair Plot of Continuous Features by Condition', y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 6
#       4 # Example 1: Violin Plots
#       5 plt.figure(figsize=(10, 6))
# ----> 6 sns.violinplot(data=df, x='condition', y='num_events', hue='score', split=True)
#       7 plt.title('Violin Plot of num_events by Condition and Score')
#       8 plt.xlabel('Condition')
#
# File c:\Users\madal\anaconda3\envs\ultraleap\lib\site-packages\seaborn\categorical.py:2305, in violinplot(data, x, y, hue, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2297 def violinplot(
#    2298     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2299     bw="scott", cut=2, scale="area", scale_hue=True, gridsize=100,
#    (...)
#    2302     ax=None, **kwargs,
#    2303 ):
# -> 2305     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2306                              bw, cut, scale, scale_hue, gridsize,
#    2307                              width, inner, split, dodge, orient, linewidth,
#    2308                              color, palette, saturation)
#    2310     if ax is None:
#    2311         ax = plt.gca()
#
# File c:\Users\madal\anaconda3\envs\ultraleap\lib\site-packages\seaborn\categorical.py:920, in _ViolinPlotter.__init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     918 if split and self.hue_names is not None and len(self.hue_names) != 2:
#     919     msg = "There must be exactly two hue levels to use `split`.'"
# --> 920     raise ValueError(msg)
#     921 self.split = split
#     923 if linewidth is None:
#
# ValueError: There must be exactly two hue levels to use `split`.'

# %%
# Set the style of seaborn plots
sns.set(style="whitegrid")

# Example: Violin Plots
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='condition', y='num_events', hue='score')
plt.title('Violin Plot of num_events by Condition and Score')
plt.xlabel('Condition')
plt.ylabel('num_events')
plt.legend(title='Score')
plt.show()
